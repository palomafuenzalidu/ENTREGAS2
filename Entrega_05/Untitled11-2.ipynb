# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)

# %%
# !pip install plotly


import pandas as pd
import plotly.express as px


df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/OSCARS_con_streaming-7.csv", sep=";")


df['Tipo'] = df['es_streaming'].map({1: 'Streaming', 0: 'Tradicional'})


nominaciones = df.groupby(['Year', 'Tipo']).size().reset_index(name='Nominaciones')


victorias = df[df['winner'] == 1].groupby(['Year', 'Tipo']).size().reset_index(name='Victorias')


df_linea = pd.merge(nominaciones, victorias, on=['Year', 'Tipo'], how='left').fillna(0)


df_long = pd.melt(
    df_linea,
    id_vars=['Year', 'Tipo'],
    value_vars=['Nominaciones', 'Victorias'],
    var_name='Métrica',
    value_name='Total'
)


fig = px.line(
    df_long,
    x='Year',
    y='Total',
    color='Tipo',
    line_dash='Métrica',
    markers=True,
    title='Evolución de nominaciones y victorias: Streaming vs Tradicional',
    color_discrete_map={
        'Streaming': '#800020',
        'Tradicional': '#C5A300'
    }
)

fig.update_layout(
    plot_bgcolor='white',
    yaxis_title='Cantidad',
    xaxis_title='Año',
    legend_title='Tipo de Distribución'
)


fig.show()

fig.write_html("/content/nominaciones_vs_victorias_streaming.html")
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4344026a-3ebe-4d07-b718-9bc61b1c9103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4344026a-3ebe-4d07-b718-9bc61b1c9103")) {                    Plotly.newPlot(                        "4344026a-3ebe-4d07-b718-9bc61b1c9103",                        [{"hovertemplate":"Tipo=Streaming\u003cbr\u003eMétrica=Nominaciones\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Streaming, Nominaciones","line":{"color":"#800020","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Streaming, Nominaciones","orientation":"v","showlegend":true,"x":[1997,1998,1999,2000,2001,2002,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[17.0,16.0,16.0,8.0,14.0,13.0,7.0,4.0,33.0,29.0,34.0,23.0,48.0,29.0,9.0,39.0,28.0,52.0,59.0,16.0,29.0,33.0,57.0,45.0,54.0,82.0,88.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tipo=Streaming\u003cbr\u003eMétrica=Victorias\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Streaming, Victorias","line":{"color":"#800020","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Streaming, Victorias","orientation":"v","showlegend":true,"x":[1997,1998,1999,2000,2001,2002,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[11.0,5.0,5.0,2.0,5.0,2.0,1.0,0.0,9.0,6.0,7.0,2.0,11.0,8.0,0.0,10.0,7.0,14.0,15.0,1.0,5.0,5.0,9.0,7.0,10.0,19.0,17.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tipo=Tradicional\u003cbr\u003eMétrica=Nominaciones\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tradicional, Nominaciones","line":{"color":"#C5A300","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Tradicional, Nominaciones","orientation":"v","showlegend":true,"x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[120.0,134.0,110.0,121.0,123.0,114.0,122.0,122.0,125.0,97.0,98.0,84.0,117.0,87.0,103.0,127.0,108.0,119.0,83.0,85.0,122.0,106.0,112.0,63.0,79.0,79.0,58.0,50.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tipo=Tradicional\u003cbr\u003eMétrica=Victorias\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tradicional, Victorias","line":{"color":"#C5A300","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Tradicional, Victorias","orientation":"v","showlegend":true,"x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[36.0,57.0,36.0,44.0,47.0,37.0,36.0,40.0,44.0,32.0,32.0,24.0,41.0,28.0,29.0,39.0,39.0,43.0,24.0,31.0,39.0,33.0,40.0,16.0,20.0,26.0,24.0,24.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %%
# !pip install plotly


import pandas as pd
import plotly.express as px


file_path = '/content/OSCARS_con_streaming-7.csv'
df = pd.read_csv(file_path, sep=';')


dist_cols = ['dist_1', 'dist_2', 'dist_3', 'dist_4', 'dist_5']
df_long = df.melt(
    id_vars=['Year', 'winner', 'es_streaming'],
    value_vars=dist_cols,
    var_name='dist_num',
    value_name='Distribuidora'
)


df_long = df_long[df_long['Distribuidora'] != '0']
df_long = df_long.dropna(subset=['Distribuidora'])


df_long['Tipo'] = df_long['es_streaming'].map({1: 'Streaming', 0: 'Tradicional'})

fig = px.strip(
    df_long,
    x='Year',
    y='Distribuidora',
    color='Tipo',
    hover_data=['winner'],
    stripmode='overlay',
    title='Evolución de la presencia de distribuidoras (Streaming vs Tradicionales)',
)

fig.update_traces(jitter=0.6, marker=dict(size=8, opacity=0.7))
fig.update_layout(yaxis={'categoryorder': 'total descending'})
fig.show()
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1-778283422.py in <cell line: 0>()
#      12 # 4️⃣ Leer el archivo CSV (ajusta la ruta)
#      13 file_path = '/content/OSCARS_con_streaming-7.csv'
# ---> 14 df = pd.read_csv(file_path, sep=';')
#      15
#      16 # 5️⃣ Convertir de ancho a largo: todas las distribuidoras en una columna
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/OSCARS_con_streaming-7.csv'
